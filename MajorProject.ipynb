# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
d1 = pd.read_csv('/content/drive/MyDrive/data/GP1_0.6_marker.csv')
d2 = pd.read_csv('/content/drive/MyDrive/data/GP1_0.8_marker.csv')
d3 = pd.read_csv('/content/drive/MyDrive/dataset/dataset1.csv')

# %%
d1.head()
# Out:
#     L_FCC_x   L_FM1_x   L_FM2_x   L_FM5_x   R_FCC_x   R_FM1_x   R_FM2_x  \
# 0  1.127087  1.332534  1.328893  1.305142  0.804407  1.017605  1.017485
# 1  1.131831  1.337421  1.333921  1.310700  0.802088  1.015296  1.015148
# 2  1.136807  1.342521  1.339171  1.316510  0.799617  1.012833  1.012659
# 3  1.141961  1.347770  1.344579  1.322506  0.797009  1.010229  1.010033
# 4  1.147230  1.353103  1.350078  1.328615  0.794281  1.007500  1.007287
#
#     R_FM5_x   L_FCC_y   L_FM1_y  ...   R_FM2_y   R_FM5_y   L_FCC_z   L_FM1_z  \
# 0  0.991847  0.575397  0.587244  ...  0.448289  0.396237  0.090627  0.084655
# 1  0.989509  0.575327  0.586249  ...  0.448250  0.396193  0.090195  0.086384
# 2  0.987012  0.575228  0.585174  ...  0.448206  0.396145  0.089767  0.088228
# 3  0.984370  0.575094  0.584023  ...  0.448160  0.396093  0.089354  0.090171
# 4  0.981602  0.574925  0.582801  ...  0.448109  0.396038  0.088963  0.092198
#
#     L_FM2_z   L_FM5_z   R_FCC_z   R_FM1_z   R_FM2_z   R_FM5_z
# ...

# %%
d2.head()
# Out:
#     L_FCC_x   L_FM1_x   L_FM2_x   L_FM5_x   R_FCC_x   R_FM1_x   R_FM2_x  \
# 0  0.570443  0.779472  0.781610  0.764915  0.752671  0.963455  0.961456
# 1  0.567284  0.776336  0.778602  0.761761  0.759216  0.970223  0.968129
# 2  0.563920  0.772992  0.775377  0.758397  0.766173  0.977402  0.975211
# 3  0.560371  0.769458  0.771950  0.754845  0.773495  0.984937  0.982647
# 4  0.556662  0.765758  0.768342  0.751126  0.781122  0.992765  0.990378
#
#     R_FM5_x   L_FCC_y   L_FM1_y  ...   R_FM2_y   R_FM5_y   L_FCC_z   L_FM1_z  \
# 0  0.931390  0.561532  0.535632  ...  0.414943  0.369149  0.081882  0.064970
# 1  0.938391  0.561540  0.535614  ...  0.414677  0.368786  0.081948  0.064903
# 2  0.945811  0.561546  0.535597  ...  0.414398  0.368410  0.082017  0.064828
# 3  0.953592  0.561546  0.535579  ...  0.414108  0.368026  0.082089  0.064745
# 4  0.961668  0.561541  0.535561  ...  0.413811  0.367639  0.082163  0.064655
#
#     L_FM2_z   L_FM5_z   R_FCC_z   R_FM1_z   R_FM2_z   R_FM5_z
# ...

# %%
d3['target1'] = np.where(d3['forcel'] > 620, 1, 0)
d3['target2'] = np.where(d3['forcer'] > 620, 1, 0)
d3.head()
# Out:
#    forcel  forcer  target1  target2
# 0  260.26  874.28        0        1
# 1  260.26  874.28        0        1
# 2  381.04  852.72        0        1
# 3  466.73  827.20        0        1
# 4  508.20  789.80        0        1

# %%
print(d3.isnull().sum())
# Out:
# forcel     0
# forcer     0
# target1    0
# target2    0
# dtype: int64

# %%
d3.dropna()
# Out:
#        forcel  forcer  target1  target2
# 0      260.26  874.28        0        1
# 1      260.26  874.28        0        1
# 2      381.04  852.72        0        1
# 3      466.73  827.20        0        1
# 4      508.20  789.80        0        1
# ...       ...     ...      ...      ...
# 11995  854.59    1.00        1        0
# 11996  867.68    1.00        1        0
# 11997  877.14    1.00        1        0
# 11998  879.34    1.00        1        0
# 11999   24.89  458.98        0        0
#
# [12000 rows x 4 columns]

# %%
print(d1.isnull().sum())
# Out:
# L_FCC_x    0
# L_FM1_x    0
# L_FM2_x    0
# L_FM5_x    0
# R_FCC_x    0
# R_FM1_x    0
# R_FM2_x    0
# R_FM5_x    0
# L_FCC_y    0
# L_FM1_y    0
# L_FM2_y    0
# L_FM5_y    0
# R_FCC_y    0
# R_FM1_y    0
# R_FM2_y    0
# R_FM5_y    0
# L_FCC_z    0
# L_FM1_z    0
# L_FM2_z    0
# L_FM5_z    0
# R_FCC_z    0
# R_FM1_z    0
# R_FM2_z    0
# R_FM5_z    0
# dtype: int64

# %%
print(d2.isnull().sum())
# Out:
# L_FCC_x    0
# L_FM1_x    0
# L_FM2_x    0
# L_FM5_x    0
# R_FCC_x    0
# R_FM1_x    0
# R_FM2_x    0
# R_FM5_x    0
# L_FCC_y    0
# L_FM1_y    0
# L_FM2_y    0
# L_FM5_y    0
# R_FCC_y    0
# R_FM1_y    0
# R_FM2_y    0
# R_FM5_y    0
# L_FCC_z    0
# L_FM1_z    0
# L_FM2_z    0
# L_FM5_z    0
# R_FCC_z    0
# R_FM1_z    0
# R_FM2_z    0
# R_FM5_z    0
# dtype: int64

# %%
Q1 = d1.quantile(0.25)
Q3 = d1.quantile(0.75)
IQR = Q3 - Q1
outliers = ((d1 < (Q1 - 1.5 * IQR)) | (d1 > (Q3 + 1.5 * IQR))).sum()
print(outliers)
# Out:
# L_FCC_x       0
# L_FM1_x       0
# L_FM2_x       0
# L_FM5_x       0
# R_FCC_x       0
# R_FM1_x       0
# R_FM2_x       0
# R_FM5_x       0
# L_FCC_y      18
# L_FM1_y      25
# L_FM2_y      23
# L_FM5_y      70
# R_FCC_y      89
# R_FM1_y      21
# R_FM2_y      24
# R_FM5_y     170
# L_FCC_z    1453
# L_FM1_z      20
# L_FM2_z      45
# L_FM5_z     781
# R_FCC_z    1427
# R_FM1_z      46
# R_FM2_z      55
# R_FM5_z    1101
# dtype: int64

# %%
from scipy import stats
z_scores = np.abs(stats.zscore(d1))
threshold = 3
outliers = np.where(z_scores > threshold)

# Remove outliers
df_clean = d1[(z_scores < threshold).all(axis=1)]
print("No of outliers removed: ", len(d1) - len(df_clean))
# Out:
# No of outliers removed:  211

# %%
Q1 = d2.quantile(0.25)
Q3 = d2.quantile(0.75)
IQR = Q3 - Q1
outliers = ((d2 < (Q1 - 1.5 * IQR)) | (d2 > (Q3 + 1.5 * IQR))).sum()
print(outliers)
# Out:
# L_FCC_x       0
# L_FM1_x       0
# L_FM2_x       0
# L_FM5_x       0
# R_FCC_x       0
# R_FM1_x       0
# R_FM2_x       0
# R_FM5_x       0
# L_FCC_y     108
# L_FM1_y     116
# L_FM2_y     112
# L_FM5_y     119
# R_FCC_y      44
# R_FM1_y       0
# R_FM2_y       0
# R_FM5_y       0
# L_FCC_z     817
# L_FM1_z       0
# L_FM2_z       0
# L_FM5_z       4
# R_FCC_z    1154
# R_FM1_z       0
# R_FM2_z       3
# R_FM5_z     193
# dtype: int64

# %%
from scipy import stats
z_scores = np.abs(stats.zscore(d2))
threshold = 3
outliers = np.where(z_scores > threshold)

# Remove outliers
df_clean = d2[(z_scores < threshold).all(axis=1)]
print("No of outliers removed: ", len(d2) - len(df_clean))
# Out:
# No of outliers removed:  102

# %%
d1.shape
# Out:
# (12000, 24)

# %%
d2.shape
# Out:
# (12000, 24)

# %%
d3['target1'] = np.where(d3['forcel'] > 620, 1, 0)
d3['target2'] = np.where(d3['forcer'] > 620, 1, 0)
d3.head()
# Out:
#    forcel  forcer  target1  target2
# 0  260.26  874.28        0        1
# 1  260.26  874.28        0        1
# 2  381.04  852.72        0        1
# 3  466.73  827.20        0        1
# 4  508.20  789.80        0        1

# %%
d3.dropna()
# Out:
#        forcel  forcer  target1  target2
# 0      260.26  874.28        0        1
# 1      260.26  874.28        0        1
# 2      381.04  852.72        0        1
# 3      466.73  827.20        0        1
# 4      508.20  789.80        0        1
# ...       ...     ...      ...      ...
# 11995  854.59    1.00        1        0
# 11996  867.68    1.00        1        0
# 11997  877.14    1.00        1        0
# 11998  879.34    1.00        1        0
# 11999   24.89  458.98        0        0
#
# [12000 rows x 4 columns]

# %%
import statsmodels.api as sm
y = d1.iloc[:, 0].values
X = d1.iloc[:, 1:].values
X = sm.add_constant(X)

model = sm.OLS(y, X)
results = model.fit()

print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                  1.000
# Method:                 Least Squares   F-statistic:                 1.937e+06
# Date:                Thu, 27 Apr 2023   Prob (F-statistic):               0.00
# Time:                        11:51:22   Log-Likelihood:                 52374.
# No. Observations:               12000   AIC:                        -1.047e+05
# Df Residuals:                   11976   BIC:                        -1.045e+05
# Df Model:                          23
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0920      0.010      9.222      0.000       0.072       0.112
# ...

# %%
plt.plot(d1.L_FCC_x)

# %%
plt.plot(d2.R_FCC_x)

# %%
data1 = pd.DataFrame({'secim':np.zeros(12000)})
data2 = pd.DataFrame({'secim':np.ones(12000)})

data2 = pd.concat([d2,data2],axis=1)
data1 = pd.concat([d1,data1],axis=1)

data = data1.append(data2,ignore_index=True)
data.head()
# Out:
#     L_FCC_x   L_FM1_x   L_FM2_x   L_FM5_x   R_FCC_x   R_FM1_x   R_FM2_x  \
# 0  1.127087  1.332534  1.328893  1.305142  0.804407  1.017605  1.017485
# 1  1.131831  1.337421  1.333921  1.310700  0.802088  1.015296  1.015148
# 2  1.136807  1.342521  1.339171  1.316510  0.799617  1.012833  1.012659
# 3  1.141961  1.347770  1.344579  1.322506  0.797009  1.010229  1.010033
# 4  1.147230  1.353103  1.350078  1.328615  0.794281  1.007500  1.007287
#
#     R_FM5_x   L_FCC_y   L_FM1_y  ...   R_FM5_y   L_FCC_z   L_FM1_z   L_FM2_z  \
# 0  0.991847  0.575397  0.587244  ...  0.396237  0.090627  0.084655  0.095734
# 1  0.989509  0.575327  0.586249  ...  0.396193  0.090195  0.086384  0.097342
# 2  0.987012  0.575228  0.585174  ...  0.396145  0.089767  0.088228  0.099043
# 3  0.984370  0.575094  0.584023  ...  0.396093  0.089354  0.090171  0.100820
# 4  0.981602  0.574925  0.582801  ...  0.396038  0.088963  0.092198  0.102656
#
#     L_FM5_z   R_FCC_z   R_FM1_z   R_FM2_z   R_FM5_z  secim
# ...

# %% [markdown]
# **Y = secim = classes , x = data without classes**

# %%
x = data.drop(["secim"],axis=1)
y = data.secim.values
x.head()
# Out:
#     L_FCC_x   L_FM1_x   L_FM2_x   L_FM5_x   R_FCC_x   R_FM1_x   R_FM2_x  \
# 0  1.127087  1.332534  1.328893  1.305142  0.804407  1.017605  1.017485
# 1  1.131831  1.337421  1.333921  1.310700  0.802088  1.015296  1.015148
# 2  1.136807  1.342521  1.339171  1.316510  0.799617  1.012833  1.012659
# 3  1.141961  1.347770  1.344579  1.322506  0.797009  1.010229  1.010033
# 4  1.147230  1.353103  1.350078  1.328615  0.794281  1.007500  1.007287
#
#     R_FM5_x   L_FCC_y   L_FM1_y  ...   R_FM2_y   R_FM5_y   L_FCC_z   L_FM1_z  \
# 0  0.991847  0.575397  0.587244  ...  0.448289  0.396237  0.090627  0.084655
# 1  0.989509  0.575327  0.586249  ...  0.448250  0.396193  0.090195  0.086384
# 2  0.987012  0.575228  0.585174  ...  0.448206  0.396145  0.089767  0.088228
# 3  0.984370  0.575094  0.584023  ...  0.448160  0.396093  0.089354  0.090171
# 4  0.981602  0.574925  0.582801  ...  0.448109  0.396038  0.088963  0.092198
#
#     L_FM2_z   L_FM5_z   R_FCC_z   R_FM1_z   R_FM2_z   R_FM5_z
# ...

# %%
from sklearn.decomposition import PCA

# Assuming your input features are stored in the 'X' variable as a numpy array
pca = PCA(n_components=10)  # Set the desired number of components
X_reduced = pca.fit_transform(X)

# %%
import seaborn as sb

plt.style.use("seaborn")
d1.corr()
# Out:
#           L_FCC_x   L_FM1_x   L_FM2_x   L_FM5_x   R_FCC_x   R_FM1_x   R_FM2_x  \
# L_FCC_x  1.000000  0.991236  0.989877  0.984630 -0.794607 -0.768455 -0.767535
# L_FM1_x  0.991236  1.000000  0.999842  0.998576 -0.772035 -0.751165 -0.750833
# L_FM2_x  0.989877  0.999842  1.000000  0.999291 -0.771443 -0.751400 -0.751115
# L_FM5_x  0.984630  0.998576  0.999291  1.000000 -0.765059 -0.746754 -0.746636
# R_FCC_x -0.794607 -0.772035 -0.771443 -0.765059  1.000000  0.992537  0.991729
# R_FM1_x -0.768455 -0.751165 -0.751400 -0.746754  0.992537  1.000000  0.999937
# R_FM2_x -0.767535 -0.750833 -0.751115 -0.746636  0.991729  0.999937  1.000000
# R_FM5_x -0.762356 -0.747005 -0.747469 -0.743430  0.988710  0.999377  0.999670
# L_FCC_y  0.168090  0.170131  0.172060  0.174565  0.031396  0.040511  0.040432
# L_FM1_y  0.200122  0.147760  0.133754  0.106185 -0.038676  0.010548  0.013263
# L_FM2_y  0.189602  0.136660  0.122578  0.094902 -0.031518  0.017806  0.020515
# ...

# %%
p1 = sb.heatmap(d1.corr())
p1
# Out:
# <Axes: >

# %% [markdown]
# # GAIT ANALYSIS

# %%
d = r"/content/data"

# %%
from mpl_toolkits.mplot3d import Axes3D
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
def datanormalizer(data):
    a = 1
    b = 0
    c = 0
    newData = pd.DataFrame(index=np.arange(0,60),columns=['FP1_x','FP2_x','FP1_y','FP2_y','FP1_z','FP2_z'])
    for each in data.index:
        a = a+1
        if a%1000 == 0:
            newData.iloc[c] = data.iloc[b:a,:].sum()/1000
            b = a
            c = c+1
    return newData
data = pd.read_csv('/content/drive/MyDrive/data/GP1_0.6_force.csv')
data.head()
# Out:
#    FP1_x     FP2_x  FP1_y      FP2_y  FP1_z       FP2_z
# 0    0.0 -9.537293    0.0  30.241894    0.0  777.790222
# 1    0.0 -8.993257    0.0  30.251348    0.0  777.832886
# 2    0.0 -8.459884    0.0  30.250864    0.0  777.852966
# 3    0.0 -7.937055    0.0  30.241360    0.0  777.852539
# 4    0.0 -7.424666    0.0  30.223719    0.0  777.833374

# %%
timer = np.arange(0,60000)
plt.scatter(timer,data['FP1_x'],color="plum")
plt.scatter(timer,data['FP2_x'],color="violet")
plt.xlabel('Time in mS')
plt.ylabel('Force')
plt.title('Change in x-axis force with respect to time')
plt.grid()
plt.show()

# %% [markdown]
# As you see above, the right and left foots are work reversible.Lets look y-axis

# %%
plt.scatter(timer,data['FP1_y'],color="fuchsia")
plt.scatter(timer,data['FP2_y'],color="aquamarine")
plt.xlabel('Time')
plt.ylabel('Force')
plt.title('Change in y-axis force with respect to time')
plt.grid()
plt.show()

# %% [markdown]
# It's so normal that the right and left foot looks reflection of each other.So, let's check z axis too.

# %%
plt.scatter(timer,data['FP1_z'],color="black")
plt.scatter(timer,data['FP2_z'],color="salmon")
plt.xlabel('Time')
plt.ylabel('Force')
plt.title('Change in z-axis force with respect to time')
plt.grid()
plt.show()

# %% [markdown]
# We visualize the x,y and z axis of force.Also we can visualize the axis in a graph together too

# %%
fig = plt.figure()
ax = fig.add_subplot(111,projection='3d')
ax.scatter(data['FP1_x'],data['FP1_y'], data['FP1_z'], color='steelblue', marker='o')
ax.scatter(data['FP2_x'],data['FP2_y'], data['FP2_z'], color='deeppink', marker='.')
ax.set_xlabel('X axis')
ax.set_ylabel('Y axis')
ax.set_zlabel('Z axis')
plt.title("3D Left-Right Foot Force Cloud")
plt.show()

# %% [markdown]
# visualize data with lower samples to see more basicly

# %%
q = datanormalizer(data=data)

plt.scatter(np.arange(0,60),q['FP1_x'])
plt.scatter(np.arange(0,60),q['FP2_x'])
plt.title('Decreased data')
plt.xlabel('Sample Data')
plt.ylabel('X label data')
plt.show()

# %%
data = pd.read_csv('/content/drive/MyDrive/data/GP1_0.6_marker.csv')

# %% [markdown]
# We choose LRFCC sensor data to visualize with both right and left foot.

# %%
timer = np.arange(0,12000)
plt.scatter(timer,data['L_FCC_x'],color='turquoise')
plt.scatter(timer,data['R_FCC_x'],color='hotpink')
plt.title('X-axis marker position')
plt.xlabel('time')
plt.ylabel('Foot-position in x-axis')
plt.grid()
plt.show()

# %% [markdown]
# Let's look y axis of LRFM1 sensor data to see diffrent variations of sensor data.

# %%
plt.scatter(timer,data['L_FM1_y'],c='orchid')
plt.scatter(timer,data['R_FM1_y'],c='mediumvioletred')
plt.title('Y-axis position')
plt.xlabel('time')
plt.ylabel('Foot-position in y-axis')
plt.grid()
plt.show()

# %% [markdown]
# Let's look z axis change of LRFM2 sensor.

# %%
plt.scatter(timer,data['L_FM2_z'],c='plum')
plt.scatter(timer,data['R_FM2_z'],c ='purple')
plt.xlabel('time')
plt.ylabel('Foot-position in z-axis')
plt.title('Z-axis position')
plt.grid()
plt.show()

# %% [markdown]
# Let's visualize all axis in 3D graph.

# %%
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure()
ax = fig.add_subplot(111,projection='3d')
ax.scatter(data['L_FCC_x'],data['L_FCC_y'], data['L_FCC_z'], color='palevioletred', marker='o')
ax.scatter(data['R_FCC_x'],data['R_FCC_y'], data['R_FCC_z'], color='lightcoral', marker='.')
ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
ax.set_zlabel('Z Label')
plt.title("3D Right-Left foot imaging")
plt.show()

# %% [markdown]
#  **SPLIT THE DATA AS TRAIN AD TEST**

# %%
from sklearn.model_selection import train_test_split
x_train, x_test,y_train,y_test = train_test_split(x,y,test_size=0.6,random_state=42)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(x_train)
X_test_scaled = scaler.transform(x_test)

# %% [markdown]
# **SVM**

# %%
from sklearn.svm import SVC

svm = SVC(random_state = 6)
svm.fit(x_train,y_train)
print("acc of svm is :",svm.score(x_test,y_test))
# Out:
# acc of svm is : 0.9320138888888889

# %% [markdown]
# **NAIVE BAYES CLASSIFIER**

# %%
from sklearn.naive_bayes import GaussianNB

nb = GaussianNB()
nb.fit(x_train,y_train)
print('accuracy of bayes in test data is :', nb.score(x_test,y_test))
# Out:
# accuracy of bayes in test data is : 0.8097222222222222

# %% [markdown]
# **LOGISTIC REGRESSION**

# %%
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression()
lr.fit(x_train,y_train)
print("test accuracy for Log Regressin is  {}".format(lr.score(x_test,y_test)))
# Out:
# test accuracy for Log Regressin is  0.9091666666666667

# %% [markdown]
# **KNN**

# %%
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier(n_neighbors = 100) #n_neighbors = k
knn.fit(x_train,y_train)
prediction = knn.predict(x_test)

print("k={} nn score:{}".format(100,knn.score(x_test,y_test)))
# Out:
# k=100 nn score:0.9734722222222222

# %%
from sklearn.tree import DecisionTreeClassifier

dt = DecisionTreeClassifier()
dt.fit(x_train,y_train)
print('Accuracy of dec tree in test data is:',dt.score(x_test,y_test))
# Out:
# Accuracy of dec tree in test data is: 0.9842361111111111

# %%
from sklearn.ensemble import BaggingClassifier
from sklearn.metrics import accuracy_score

bag_model = BaggingClassifier(
    estimator = DecisionTreeClassifier(),
    n_estimators = 150,
    max_samples = 0.1,
    oob_score = True,
    random_state = 42
)

bag_model.fit(x_train,y_train)
print(bag_model.oob_score_)
# Out:
# 0.9861458333333334

# %%
print("Accuracy of the bagging classifier: ", bag_model.score(x_test,y_test))
# Out:
# Accuracy of the bagging classifier:  0.9873611111111111

# %%
from sklearn.model_selection import cross_val_score

# %%
from sklearn.ensemble import BaggingClassifier
bag_model = BaggingClassifier(
    estimator=DecisionTreeClassifier(),
    n_estimators=180,
    max_samples =0.3,
    oob_score = True,
    random_state = 0
)

scores  = cross_val_score(bag_model,x,y,cv = 12)
scores.mean()
# Out:
# 0.9355416666666666

# %%
bag_model.fit(x_train,y_train)
# Out:
# BaggingClassifier(estimator=DecisionTreeClassifier(), max_samples=0.3,
#                   n_estimators=180, oob_score=True, random_state=0)

# %%
def predict_neuro_disease(force1, force2):
    X = d3[['forcel', 'forcer']]
    y = d3[['target1', 'target2']].apply(lambda x: 'Yes' if x[0]==1 and x[1]==1 else 'No', axis=1)
    base_classifier = DecisionTreeClassifier()
    bagging_classifier = BaggingClassifier(base_classifier, n_estimators=10, random_state=42)
    bagging_classifier.fit(X, y)
    user_input = [[force1, force2]]
    prediction = bagging_classifier.predict(user_input)[0]
    if prediction == 'Yes':
        return "The person has a neurological disease."
    else:
        return "The person does not have a neurological disease."

# %%
force1 = int(input("Enter the force exerted by left foot: "))
force2 = int(input("Enter the force exerted by right foot: "))
result = predict_neuro_disease(force1, force2)
print(result)
# Out:
# Enter the force exerted by left foot: 246
# Enter the force exerted by right foot: 365
# The person does not have a neurological disease.

# %% [markdown]
# Confusion Matrix

# %%
from sklearn.metrics import confusion_matrix
y_pred = bag_model.predict(X_test_scaled)

print("Confusion Matrix: ")
print(confusion_matrix(y_test, y_pred))
# Out:
# Confusion Matrix:
# [[   0 7237]
#  [   0 7163]]
